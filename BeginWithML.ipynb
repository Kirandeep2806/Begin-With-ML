# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirandeep2806/Begin-With-ML/blob/main/BeginWithML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/heart.csv")

# %%
data
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up           0.0
# 1     49   F           NAP  ...      1.0      Flat           1.0
# 2     37   M           ATA  ...      0.0        Up           0.0
# 3     48   F           ASY  ...      1.5      Flat           1.0
# 4     54   M           NAP  ...      0.0        Up           0.0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat           1.0
# 914   68   M           ASY  ...      3.4      Flat           1.0
# 915   57   M           ASY  ...      1.2      Flat           1.0
# 916   57   F           ATA  ...      0.0      Flat           1.0
# 917   38   M           NAP  ...      0.0        Up           0.0
#
# [918 rows x 12 columns]

# %%
data.head(10)
# Out:
#    Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0   40   M           ATA  ...      0.0        Up           0.0
# 1   49   F           NAP  ...      1.0      Flat           1.0
# 2   37   M           ATA  ...      0.0        Up           0.0
# 3   48   F           ASY  ...      1.5      Flat           1.0
# 4   54   M           NAP  ...      0.0        Up           0.0
# 5   39   M           NAP  ...      0.0        Up           0.0
# 6   45   F           ATA  ...      0.0        Up           0.0
# 7   54   M           ATA  ...      0.0        Up           0.0
# 8   37   M           ASY  ...      1.5      Flat           1.0
# 9   48   F           ATA  ...      0.0        Up           0.0
#
# [10 rows x 12 columns]

# %%
data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP         float64
# Cholesterol       float64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease      float64
# dtype: object

# %%
data.describe()
# Out:
#               Age   RestingBP  ...     Oldpeak  HeartDisease
# count  918.000000  917.000000  ...  915.000000    917.000000
# mean    53.510893  132.377317  ...    0.887432      0.553980
# std      9.432617   18.515114  ...    1.067239      0.497349
# min     28.000000    0.000000  ...   -2.600000      0.000000
# 25%     47.000000  120.000000  ...    0.000000      0.000000
# 50%     54.000000  130.000000  ...    0.600000      1.000000
# 75%     60.000000  140.000000  ...    1.500000      1.000000
# max     77.000000  200.000000  ...    6.200000      1.000000
#
# [8 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       917 non-null    float64
#  4   Cholesterol     916 non-null    float64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         915 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    917 non-null    float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 86.2+ KB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(data["Age"], bins=10)
plt.xlabel("Age")
plt.ylabel("No. of people")
plt.title("Frequency of ages")
plt.show()

# %%
data["ChestPainType"].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
data["RestingECG"].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
plt.scatter(x=data["Age"], y=data["MaxHR"], color='red')
plt.xlabel("Age")
plt.ylabel("Max Heart Rate")
plt.title("Age v/s Max Heart Rate")
plt.show()

# %%
df = data.groupby("Sex")

# %%
sex = ["Male", "Female"]
recordCount = []
for value in df.groups.values():
  recordCount.append(len(value))

# %%
plt.pie(recordCount, labels=sex)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fba401df850>,
# ...
#  [Text(0.8686626780128879, 0.6748519480800794, 'Male'),
#   Text(-0.8686626780128879, -0.6748519480800792, 'Female')])

# %%
plt.plot(data["MaxHR"])

# %%
# The above graph in the form of scatter plot
plt.scatter(x=[i for i in range(data.shape[0])] ,y=data["MaxHR"])

# %%
plt.boxplot(data["Cholesterol"])
# Not displaying the graph due to empty fields in the cholesterol
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fba40103790>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fba4010a750>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fba40090790>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fba40090250>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fba401eb4d0>,
#   <matplotlib.lines.Line2D at 0x7fba4010a210>]}

# %%
data["MaxHR"].mean()
# Out:
# 136.80936819172112

# %%
data["Cholesterol"].median()
# Out:
# 223.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       917 non-null    float64
#  4   Cholesterol     916 non-null    float64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         915 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    917 non-null    float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 86.2+ KB

# %%
data.groupby(["Sex"])["Cholesterol"].mean()
# Selects all the Females and averages it's cholestrol
# Selects all the Males and averages it's cholestrol
# Out:
# Sex
# F    241.196891
# M    187.445367
# Name: Cholesterol, dtype: float64

# %%
data.groupby(["ChestPainType", "MaxHR"])["Cholesterol"].mean()
# Selects all Female with 90 MaxHR and averages it's cholesterol
# .............
# Selects all Male with 188 MaxHR and averages it's cholesterol
# Out:
# ChestPainType  MaxHR
# ASY            60         0.0
#                63         0.0
#                67         0.0
#                69       458.0
#                71       237.0
#                         ...
# TA             178      247.0
#                180      156.0
#                182      231.0
#                185      160.0
#                190      186.0
# Name: Cholesterol, Length: 284, dtype: float64

# %%
pd.pivot_table(data, values="Cholesterol", index=["ChestPainType", "MaxHR"], aggfunc=np.mean)
# Out:
#                      Cholesterol
# ChestPainType MaxHR
# ASY           60             0.0
#               63             0.0
#               67             0.0
#               69           458.0
#               71           237.0
# ...                          ...
# TA            178          247.0
#               180          156.0
#               182          231.0
#               185          160.0
#               190          186.0
#
# [284 rows x 1 columns]

# %%
data["HeartDisease"] = data["HeartDisease"].map({1: "Yes", 0:"No"})

# %%
data
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up            No
# 1     49   F           NAP  ...      1.0      Flat           Yes
# 2     37   M           ATA  ...      0.0        Up            No
# 3     48   F           ASY  ...      1.5      Flat           Yes
# 4     54   M           NAP  ...      0.0        Up            No
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat           Yes
# 914   68   M           ASY  ...      3.4      Flat           Yes
# 915   57   M           ASY  ...      1.2      Flat           Yes
# 916   57   F           ATA  ...      0.0      Flat           Yes
# 917   38   M           NAP  ...      0.0        Up            No
#
# [918 rows x 12 columns]

# %%
def convertToInt(boolValue) -> int:
  if boolValue == "Yes":
    return 1
  if boolValue == "No":
    return 0

data["HeartDisease"] = data["HeartDisease"].map(convertToInt) # Effects on assigned value

# %%
data
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up           0.0
# 1     49   F           NAP  ...      1.0      Flat           1.0
# 2     37   M           ATA  ...      0.0        Up           0.0
# 3     48   F           ASY  ...      1.5      Flat           1.0
# 4     54   M           NAP  ...      0.0        Up           0.0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat           1.0
# 914   68   M           ASY  ...      3.4      Flat           1.0
# 915   57   M           ASY  ...      1.2      Flat           1.0
# 916   57   F           ATA  ...      0.0      Flat           1.0
# 917   38   M           NAP  ...      0.0        Up           0.0
#
# [918 rows x 12 columns]

# %%
data.describe()
# Out:
#               Age   RestingBP  ...     Oldpeak  HeartDisease
# count  918.000000  917.000000  ...  915.000000    917.000000
# mean    53.510893  132.377317  ...    0.887432      0.553980
# std      9.432617   18.515114  ...    1.067239      0.497349
# min     28.000000    0.000000  ...   -2.600000      0.000000
# 25%     47.000000  120.000000  ...    0.000000      0.000000
# 50%     54.000000  130.000000  ...    0.600000      1.000000
# 75%     60.000000  140.000000  ...    1.500000      1.000000
# max     77.000000  200.000000  ...    6.200000      1.000000
#
# [8 rows x 7 columns]

# %%
def divideByAge(row):
    if row[0] >= 28 and row[0] <40:
        return "Low age"
    if row[0] >=40 and row[0]<61:
        return "Ok"
    if row[0]>60:
        return "High age"

data["Age factor"]=data[["Age"]].apply(divideByAge, axis=1)

# %%
data
# Out:
#      Age Sex ChestPainType  ...  ST_Slope  HeartDisease  Age factor
# 0     40   M           ATA  ...        Up           0.0          Ok
# 1     49   F           NAP  ...      Flat           1.0          Ok
# 2     37   M           ATA  ...        Up           0.0     Low age
# 3     48   F           ASY  ...      Flat           1.0          Ok
# 4     54   M           NAP  ...        Up           0.0          Ok
# ..   ...  ..           ...  ...       ...           ...         ...
# 913   45   M            TA  ...      Flat           1.0          Ok
# 914   68   M           ASY  ...      Flat           1.0    High age
# 915   57   M           ASY  ...      Flat           1.0          Ok
# 916   57   F           ATA  ...      Flat           1.0          Ok
# 917   38   M           NAP  ...        Up           0.0     Low age
#
# [918 rows x 13 columns]

# %%
print("The no.of rows are :", data.index.stop)
# Out:
# The no.of rows are : 918

# %%
q1 = data["Cholesterol"].quantile(.25)
q1
# Out:
# 173.0

# %%
q2 = data["Cholesterol"].quantile(.5)
q2
# Out:
# 223.0

# %%
q3 = data["Cholesterol"].quantile(.75)
q3
# Out:
# 267.0

# %%
interQuantileRange = q3 - q1
interQuantileRange
# Out:
# 94.0

# %%
lowerLimit = q1 - (1.5*interQuantileRange)
lowerLimit
# Out:
# 32.0

# %%
upperLimit = q3 + (1.5*interQuantileRange)
upperLimit
# Out:
# 408.0

# %%
# Let's find how many outliers are present

def getOutliers(rowName):
  if rowName[0] > q3:
    return True
  if rowName[0] < q1:
    return True
  else:
    return False

temp = data[["Cholesterol"]].apply(getOutliers, axis=1)

# %%
# Series is 1-D array so we need to choose the values that are True and we can get it by

outlierCount = len(temp[temp == True])
print(outlierCount)

# From the Series temp we are selecting each element whose value is True and counting the total length
# Out:
# 455

# %%
import seaborn as sns

# %%
plt.boxplot(data["Cholesterol"])
# Not displaying the graph due to empty fields in the cholesterol. So we use seaborn to rectify this issue
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fba40086c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fba4008dc10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fba40013c50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fba40013710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fba400bcc90>,
#   <matplotlib.lines.Line2D at 0x7fba4008d6d0>]}

# %%
sns.boxplot(x=data["Cholesterol"])

# %%
# Treating the outliers

def limit_imputer(value):
  if value < lowerLimit:
    return lowerLimit
  elif value > upperLimit:
    return upperLimit
  else:
    return value

# %%
data["Cholesterol"] = data["Cholesterol"].apply(limit_imputer)
data["Cholesterol"].max()
# Out:
# 408.0

# %%
sns.boxplot(x=data["Cholesterol"])

# %%
# Let's see the deletion of NaN field rows in the table

# data.describe()
print("Before applying Dropna :", data.shape)
data.dropna(inplace=True, subset=["Oldpeak"])
# Delete's the rows which has NaN in the Oldpek column
# If inplace is set to True it effects on the original dataframe else it will return a dataframe with modified values
# Out:
# Before applying Dropna : (918, 13)

# %%
print("After applying Dropna :",data.shape)
# Out:
# After applying Dropna : (915, 13)

# %%
# Replacing NaN values with some condition
data.info()
# Still RestingBP, Cholesterol and HeartDisease are having NaN values. So, lets replace them with some condition.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 915 entries, 0 to 917
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             915 non-null    int64
#  1   Sex             915 non-null    object
#  2   ChestPainType   915 non-null    object
#  3   RestingBP       914 non-null    float64
#  4   Cholesterol     913 non-null    float64
#  5   FastingBS       915 non-null    int64
#  6   RestingECG      915 non-null    object
#  7   MaxHR           915 non-null    int64
#  8   ExerciseAngina  915 non-null    object
#  9   Oldpeak         915 non-null    float64
#  10  ST_Slope        915 non-null    object
#  11  HeartDisease    914 non-null    float64
#  12  Age factor      915 non-null    object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 100.1+ KB

# %%
from sklearn.impute import SimpleImputer

# %%
# Fills the NaN with the mean values of respective non-NaN cols

impute = SimpleImputer(missing_values=np.nan, strategy="mean")
X = impute.fit_transform(([[1, np.nan, np.nan], [np.nan, np.nan, np.nan], [4, 5, np.nan]]))
X
# Out:
# array([[1. , 5. ],
#        [2.5, 5. ],
#        [4. , 5. ]])

# %%
# Lets apply the above one to the actual dataframe

# SimpleImputer expects 2D array but data["Cholesterol"] is a 1D Series object, so do
# 1D Series -> numpy array -> Reshape to 2D array

cholesterolValues = data["Cholesterol"].values.reshape(-1, 1) # 1D Series -> numpy array(using .values) -> Reshape to 2D array(using .reshape)
impute = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
data["Cholesterol"] = impute.fit_transform(cholesterolValues)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 915 entries, 0 to 917
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             915 non-null    int64
#  1   Sex             915 non-null    object
#  2   ChestPainType   915 non-null    object
#  3   RestingBP       914 non-null    float64
#  4   Cholesterol     915 non-null    float64
#  5   FastingBS       915 non-null    int64
#  6   RestingECG      915 non-null    object
#  7   MaxHR           915 non-null    int64
#  8   ExerciseAngina  915 non-null    object
#  9   Oldpeak         915 non-null    float64
#  10  ST_Slope        915 non-null    object
#  11  HeartDisease    914 non-null    float64
#  12  Age factor      915 non-null    object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 100.1+ KB

# %%
# Here we aren't using ExerciseAngina and ST_Slope in our dataset, so lets delete it

data.drop(labels=["ST_Slope", "ExerciseAngina"], axis=1, inplace=True) # or data.drop(columns=["ST_Slope", "ExerciseAngina"], inplace=True)

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  ...  MaxHR  Oldpeak HeartDisease  Age factor
# 0   40   M           ATA      140.0  ...    172      0.0          0.0          Ok
# 1   49   F           NAP      160.0  ...    156      1.0          1.0          Ok
# 2   37   M           ATA      130.0  ...     98      0.0          0.0     Low age
# 3   48   F           ASY      138.0  ...    108      1.5          1.0          Ok
# 4   54   M           NAP      150.0  ...    122      0.0          0.0          Ok
#
# [5 rows x 11 columns]

# %%
# Let's save the current dataset to csv file

data.to_csv("/content/drive/MyDrive/Colab Notebooks/Updated heart.csv", index=False)

# %%
data["Age"].corr(data["Cholesterol"])
# Out:
# -0.0885057861099203

# %%
# Its like mode, frequency counter

temp = data["Age factor"].value_counts()
print(temp)
print(temp["Ok"])
# Out:
# Ok          616
# High age    220
# Low age      79
# Name: Age factor, dtype: int64
# 616

# %%
data.corr()
# Out:
#                    Age  RestingBP  ...   Oldpeak  HeartDisease
# Age           1.000000   0.259385  ...  0.260048      0.281425
# RestingBP     0.259385   1.000000  ...  0.165787      0.109571
# Cholesterol  -0.088506   0.110033  ...  0.059301     -0.219524
# FastingBS     0.197698   0.070019  ...  0.052742      0.267808
# MaxHR        -0.384641  -0.112604  ... -0.160189     -0.400536
# Oldpeak       0.260048   0.165787  ...  1.000000      0.402798
# HeartDisease  0.281425   0.109571  ...  0.402798      1.000000
#
# [7 rows x 7 columns]

# %%
data.groupby("HeartDisease")["Oldpeak"].mean().plot(kind="bar")

# %%
# Try removing sort_values() and observe the differences

data.groupby(["Age"])["MaxHR"].mean().sort_values(kind="stable").plot(kind="bar")

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
# Renaming the variable(col name)

data = data.rename(columns={"Age factor" : "Age_factor"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 915 entries, 0 to 917
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            915 non-null    int64
#  1   Sex            915 non-null    object
#  2   ChestPainType  915 non-null    object
#  3   RestingBP      914 non-null    float64
#  4   Cholesterol    915 non-null    float64
#  5   FastingBS      915 non-null    int64
#  6   RestingECG     915 non-null    object
#  7   MaxHR          915 non-null    int64
#  8   Oldpeak        915 non-null    float64
#  9   HeartDisease   914 non-null    float64
#  10  Age_factor     915 non-null    object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 85.8+ KB

# %%
# Syntax should be like ols("{numerical variable} ~ {categorical variable}")
mod = ols("MaxHR ~ Age_factor", data=data).fit()

# %%
anova_table = sm.stats.anova_lm(mod, typ=2)
anova_table
# Out:
#                    sum_sq     df          F        PR(>F)
# Age_factor   66723.725252    2.0  57.714762  2.504468e-24
# Residual    527179.142508  912.0        NaN           NaN

# %%
mod = ols("MaxHR ~ MaxHR", data=data).fit()
anova_table = sm.stats.anova_lm(mod, typ=2)
anova_table

# The PR(>F) = 0.0 i.e., 0% probablitity of alternate hypothesis
# Out:
#                 sum_sq     df             F  PR(>F)
# MaxHR     5.939029e+05    1.0  1.576774e+32     0.0
# Residual  3.438878e-24  913.0           NaN     NaN

# %%
# Now let's see the creation of the the dummy variables

withDummies_1 = pd.get_dummies(data, columns=["Age_factor"]) # Takes n cols of mentioned cols
withDummies_1
# Out:
#      Age Sex  ... Age_factor_Low age  Age_factor_Ok
# 0     40   M  ...                  0              1
# 1     49   F  ...                  0              1
# 2     37   M  ...                  1              0
# 3     48   F  ...                  0              1
# 4     54   M  ...                  0              1
# ..   ...  ..  ...                ...            ...
# 913   45   M  ...                  0              1
# 914   68   M  ...                  0              0
# 915   57   M  ...                  0              1
# 916   57   F  ...                  0              1
# 917   38   M  ...                  1              0
#
# [915 rows x 13 columns]

# %%
# Take n-1 levels of mentioned cols

withDummies_2 = pd.get_dummies(data, columns=["Age_factor"], drop_first=True)
withDummies_2
# Out:
#      Age Sex ChestPainType  ...  HeartDisease  Age_factor_Low age  Age_factor_Ok
# 0     40   M           ATA  ...           0.0                   0              1
# 1     49   F           NAP  ...           1.0                   0              1
# 2     37   M           ATA  ...           0.0                   1              0
# 3     48   F           ASY  ...           1.0                   0              1
# 4     54   M           NAP  ...           0.0                   0              1
# ..   ...  ..           ...  ...           ...                 ...            ...
# 913   45   M            TA  ...           1.0                   0              1
# 914   68   M           ASY  ...           1.0                   0              0
# 915   57   M           ASY  ...           1.0                   0              1
# 916   57   F           ATA  ...           1.0                   0              1
# 917   38   M           NAP  ...           0.0                   1              0
#
# ...

# %%
data.nunique()
# Out:
# Age               50
# Sex                2
# ChestPainType      4
# RestingBP         67
# Cholesterol      212
# FastingBS          2
# RestingECG         3
# MaxHR            119
# Oldpeak           53
# HeartDisease       2
# Age_factor         3
# dtype: int64

# %%
# let's use binning method to create 10 bins of Age w.r.t Cholesterol

Age_Table = data.groupby("Age").agg({"Cholesterol" : "mean"}).sort_values("Cholesterol", ascending=True)

# %%
Age_Table
# Out:
#      Cholesterol
# Age
# 73     32.000000
# 28    132.000000
# 72    145.000000
# 76    155.000000
# 38    158.500000
# 69    166.076923
# 34    167.857143
# 68    168.100000
# 63    169.333333
# 61    174.967742
# 62    175.885714
# 60    177.656250
# 70    180.857143
# 56    183.184211
# 59    183.942857
# 51    184.114286
# 53    185.575758
# 66    186.846154
# 74    193.428571
# 36    195.666667
# 50    196.960000
# 47    200.157895
# 35    200.363636
# 52    205.611111
# 43    207.666667
# 57    208.210526
# 64    212.590909
# 65    213.100000
# 49    215.000000
# 42    215.777778
# 46    219.833333
# 58    220.666667
# 41    221.217391
# 55    223.146341
# 32    223.400000
# 54    227.215686
# 40    229.846154
# 48    230.258065
# 45    231.111111
# 71    231.600000
# 37    236.000000
# 29    236.666667
# 30    237.000000
# 77    237.500000
# 39    239.200000
# 31    244.500000
# 44    245.000000
# 75    246.000000
# 67    248.733333
# 33    272.000000

# %%
# Now lets create 10 bins
# cut() in pandas is used to segregate the data in the bins

data["Age_Group_Cholesterol"] = pd.cut(data["Cholesterol"], bins=10, labels=["Age_Group_Cholesterol_0", "Age_Group_Cholesterol_1", "Age_Group_Cholesterol_2", "Age_Group_Cholesterol_3", "Age_Group_Cholesterol_4", "Age_Group_Cholesterol_5", "Age_Group_Cholesterol_6", "Age_Group_Cholesterol_7", "Age_Group_Cholesterol_8", "Age_Group_Cholesterol_9"], include_lowest=True)

# include_lowest=True make the first interval of te bin as inclusive

# %%
data.head()
# Out:
#    Age Sex ChestPainType  ...  HeartDisease  Age_factor    Age_Group_Cholesterol
# 0   40   M           ATA  ...           0.0          Ok  Age_Group_Cholesterol_6
# 1   49   F           NAP  ...           1.0          Ok  Age_Group_Cholesterol_3
# 2   37   M           ATA  ...           0.0     Low age  Age_Group_Cholesterol_6
# 3   48   F           ASY  ...           1.0          Ok  Age_Group_Cholesterol_4
# 4   54   M           NAP  ...           0.0          Ok  Age_Group_Cholesterol_4
#
# [5 rows x 12 columns]

# %%
# My custom code to divide to bins

divideToBins = data["Cholesterol"].max() - data["Cholesterol"].min()
divideToBins /= 10 # 10 is the no.of bins
start = data["Cholesterol"].min()
end = data["Cholesterol"].max()
i = 0
# print(start, end, divideToBins)
while start <= end:
  print(f"Bin {i} : {start} - {start + divideToBins}")
  i += 1
  start += divideToBins
# Out:
# Bin 0 : 32.0 - 69.6
# Bin 1 : 69.6 - 107.19999999999999
# Bin 2 : 107.19999999999999 - 144.79999999999998
# Bin 3 : 144.79999999999998 - 182.39999999999998
# Bin 4 : 182.39999999999998 - 219.99999999999997
# Bin 5 : 219.99999999999997 - 257.59999999999997
# Bin 6 : 257.59999999999997 - 295.2
# Bin 7 : 295.2 - 332.8
# Bin 8 : 332.8 - 370.40000000000003
# Bin 9 : 370.40000000000003 - 408.00000000000006

# %%
# data = pd.merge(data, Age_Table, left_on="Age_Group_Cholesterol", how="left", right_index=True)

# %%
data = pd.get_dummies(data, columns=["Age_Group_Cholesterol"], drop_first=True)
# If you get some error saying "None of [Index(['Age_Group_Cholesterol'], dtype='object')] are in the [columns]" then execute whole code again using Ctrl+F9

# %%
data
# Out:
#      Age  ... Age_Group_Cholesterol_Age_Group_Cholesterol_9
# 0     40  ...                                             0
# 1     49  ...                                             0
# 2     37  ...                                             0
# 3     48  ...                                             0
# 4     54  ...                                             0
# ..   ...  ...                                           ...
# 913   45  ...                                             0
# 914   68  ...                                             0
# 915   57  ...                                             0
# 916   57  ...                                             0
# 917   38  ...                                             0
#
# [915 rows x 20 columns]
